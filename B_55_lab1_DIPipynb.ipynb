# %%
import numpy as np
import cv2

# %%
img = cv2.imread('/content/lenacolor.png',1)

# %%
(h,w,d) = img.shape
print('width={}, height={}, depth={}'.format(w,h,d))
# Out:
# width=512, height=512, depth=3

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
## b. Displaying an image in gray scale mode
image = cv2.imread('/content/lenacolor.png',0)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
im = cv2.imread('/content/lenacolor.png',-1)
from google.colab.patches import cv2_imshow
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
img = cv2.imread('/content/lenabandv.jpg',1)
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=204x192>

# %%
img = cv2.imread('/content/lenabandv.jpg',0)
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=204x192>

# %%
img = cv2.imread('/content/lenabandv.jpg',-1)
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=204x192>

# %%
cv2.imwrite('lenabandv.png',img)
# Out:
# True

# %%
cv2_imshow(img)
img1 = cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=204x192>
# <PIL.Image.Image image mode=RGB size=192x204>

# %%
cv2_imshow(img)
img1 = cv2.rotate(img,cv2.ROTATE_180)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=204x192>
# <PIL.Image.Image image mode=RGB size=204x192>

# %%
cv2_imshow(img)
img1 = cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=204x192>
# <PIL.Image.Image image mode=RGB size=192x204>

# %%
# resize image

resized = cv2.resize(img, (100,100)) #Resize the image to 100x100 pixels
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image = cv2.imread('/content/cameramanbandv.png',1)
(h,w,d) = img.shape
print('width={}, height={}, depth={}'.format(w,h,d))
# Out:
# width=204, height=192, depth=3

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=648x648>

# %%
## b. Displaying an image in gray scale mode
image = cv2.imread('/content/cameramanbandv.png',0)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=648x648>

# %%
## b. Displaying an image in gray scale mode
image = cv2.imread('/content/cameramanbandv.png',-1)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=648x648>

# %%
cv2_imshow(image)
img1 = cv2.rotate(image,cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=648x648>
# <PIL.Image.Image image mode=RGB size=648x648>

# %%
# resize image

resized = cv2.resize(image, (100,100)) #Resize the image to 100x100 pixels
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>
